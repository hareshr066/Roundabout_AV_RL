# %% [markdown]
# # Safety Analysis
#
# Analyze Time-to-Collision (TTC) distributions and ride comfort (jerk profiles).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')
print('Libraries loaded!')

# %% [markdown]
# ## 1. Load Safety Results

# %%
import os
csv_path = '../results/safety_analysis_results.csv'
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    print('Safety Analysis Results:')
    print(df.to_string(index=False))
else:
    print(f'File not found: {csv_path}')
    print('Run evaluation/run_safety_analysis.py first.')

# %% [markdown]
# ## 2. TTC Distribution

# %%
print('TODO: Plot histogram of TTC values across episodes')
print('Need per-step TTC data from safety analysis.')

# %% [markdown]
# ## 3. Jerk Analysis

# %%
print('TODO: Plot jerk profiles and compare against comfort thresholds')
print('ISO 2631 suggests jerk < 2.0 m/s^3 for passenger comfort.')
